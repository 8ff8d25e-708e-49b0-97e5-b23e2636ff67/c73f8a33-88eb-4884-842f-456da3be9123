# %%
from torch import optim
import networkx as nx
import matplotlib.pyplot as plt
from pykeen.triples import TriplesFactory
import pandas as pd
from pykeen.training.callbacks import TrainingCallback
import importlib
import machine_learning
import torch
importlib.reload(machine_learning)
# Out:
# <module 'machine_learning' from '/Users/chrisdefra/Documents/oxford/KGS/c73f8a33-88eb-4884-842f-456da3be9123/assignment/machine_learning.py'>

# %%
triples_df = pd.read_csv('./data/csvs/aldosterone-triples.csv/part-00000-fd7a091f-83c1-4109-a7ab-a9dbb1a572fb-c000.csv')
triples_df
# Out:
#             _c0                        _c1                      Hormone
# 0   Aldosterone  mayCauseUnderProductionOf     Tetrahydrocorticosterone
# 1   Aldosterone  mayCauseUnderProductionOf           Tetrahydrocortisol
# 2   Aldosterone  mayCauseUnderProductionOf      20beta-Dihydrocortisone
# 3   Aldosterone  mayCauseUnderProductionOf                Pregnenetriol
# 4   Aldosterone  mayCauseUnderProductionOf  20alpha-Hydroxyprogesterone
# ..          ...                        ...                          ...
# 73  Aldosterone  mayCauseUnderProductionOf       11-Ketoetiocholanolone
# 74  Aldosterone  mayCauseUnderProductionOf       22R-Hydroxycholesterol
# 75  Aldosterone  mayCauseUnderProductionOf       Dehydroepiandrosterone
# 76  Aldosterone  mayCauseUnderProductionOf       11-deoxycorticosterone
# 77  Aldosterone  mayCauseUnderProductionOf                 Pregnanediol
#
# [78 rows x 3 columns]
